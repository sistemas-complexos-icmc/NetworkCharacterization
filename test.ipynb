# %%
from NetworkCharacterization import compute_network_measures

# %%
compute_network_measures('barabasi_linear')
# Out:
# 100%|██████████| 11/11 [00:38<00:00,  3.46s/it]
#                              clustering  closeness    size  betweenness  \
# barabasi_linear_1.edgelist     0.031815   0.333556  1000.0     1007.355
# barabasi_linear_0.edgelist     0.030730   0.333588  1000.0     1007.144
# barabasi_linear_7.edgelist     0.032496   0.335641  1000.0      997.645
# barabasi_linear_8.edgelist     0.030414   0.337688  1000.0      988.716
# barabasi_linear_10.edgelist    0.030688   0.334832  1000.0     1001.572
# barabasi_linear_4.edgelist     0.031035   0.335249  1000.0      999.627
# barabasi_linear_5.edgelist     0.029998   0.334907  1000.0     1000.802
# barabasi_linear_6.edgelist     0.031951   0.334784  1000.0     1001.733
# barabasi_linear_2.edgelist     0.033304   0.336167  1000.0      995.686
# barabasi_linear_3.edgelist     0.033697   0.336381  1000.0      994.918
# barabasi_linear_9.edgelist     0.030947   0.336356  1000.0      994.715
#
#                              average_shortest_path_lenght  eigenvector  \
# barabasi_linear_1.edgelist                       3.013710     0.076176
# barabasi_linear_0.edgelist                       3.013288     0.082018
# barabasi_linear_7.edgelist                       2.994290     0.086244
# barabasi_linear_8.edgelist                       2.976432     0.091112
# barabasi_linear_10.edgelist                      3.002144     0.079267
# barabasi_linear_4.edgelist                       2.998254     0.072591
# barabasi_linear_5.edgelist                       3.000604     0.076702
# barabasi_linear_6.edgelist                       3.002466     0.078193
# barabasi_linear_2.edgelist                       2.990372     0.083181
# barabasi_linear_3.edgelist                       2.988836     0.078896
# barabasi_linear_9.edgelist                       2.988430     0.081527
#
#                              assortativity  information_centrality  \
# barabasi_linear_1.edgelist       -0.024777                0.003434
# barabasi_linear_0.edgelist       -0.017816                0.003437
# barabasi_linear_7.edgelist       -0.037381                0.003429
# barabasi_linear_8.edgelist       -0.039734                0.003419
# barabasi_linear_10.edgelist      -0.028491                0.003423
# barabasi_linear_4.edgelist       -0.037634                0.003424
# barabasi_linear_5.edgelist       -0.025093                0.003419
# barabasi_linear_6.edgelist       -0.024320                0.003427
# barabasi_linear_2.edgelist       -0.031042                0.003428
# barabasi_linear_3.edgelist       -0.028178                0.003428
# barabasi_linear_9.edgelist       -0.040781                0.003434
#
#                              approximate_current_flow_betweenness_centrality  \
# barabasi_linear_1.edgelist                                          0.004926
# barabasi_linear_0.edgelist                                          0.005031
# barabasi_linear_7.edgelist                                          0.005003
# barabasi_linear_8.edgelist                                          0.004993
# barabasi_linear_10.edgelist                                         0.004869
# barabasi_linear_4.edgelist                                          0.004999
# barabasi_linear_5.edgelist                                          0.004817
# barabasi_linear_6.edgelist                                          0.004987
# barabasi_linear_2.edgelist                                          0.004953
# barabasi_linear_3.edgelist                                          0.004937
# barabasi_linear_9.edgelist                                          0.004964
#
#                              shannon_entropy  degree_variance
# barabasi_linear_1.edgelist          3.646755        33.773757
# barabasi_linear_0.edgelist          3.657230        34.351128
# barabasi_linear_7.edgelist          3.627943        34.639813
# barabasi_linear_8.edgelist          3.610026        30.886890
# barabasi_linear_10.edgelist         3.635039        32.330326
# barabasi_linear_4.edgelist          3.638102        33.773757
# barabasi_linear_5.edgelist          3.628932        30.020826
# barabasi_linear_6.edgelist          3.641958        32.330326
# barabasi_linear_2.edgelist          3.633562        30.598203
# barabasi_linear_3.edgelist          3.631015        33.196385
# barabasi_linear_9.edgelist          3.633848        34.062443
